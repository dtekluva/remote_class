# %%
import pandas as pd
df = pd.read_csv('nyc_weather.csv')
df_copy = df.copy()

# %%
import pandas as pd
data = pd.read_csv('countries.csv')

# %%
mask_1952 = data.year == 1952 
data[mask_1952]

# %%
mask_country = (data.country == "Nigeria") | (data.country == "China") #multiple constaint (| --> or)  and (& --> and)
niger_china = data[mask_country]
only_1952 = niger_china[niger_china.year == 1952]
only_1952
# Out:
#       country  year  population
# 288     China  1952   556263527
# 1128  Nigeria  1952    33119096

# %%
df.iloc[2]
# Out:
# EST                     1/3/2016
# Temperature                   40
# DewPoint                      21
# Humidity                      47
# Sea Level PressureIn       29.86
# VisibilityMiles               10
# WindSpeedMPH                   8
# PrecipitationIn                0
# CloudCover                     1
# Events                       NaN
# WindDirDegrees               277
# Name: 2, dtype: object

# %%
df[['EST', 'Temperature', 'Humidity']]
# Out:
#           EST  Temperature  Humidity
# 0    1/1/2016           38        52
# 1    1/2/2016           36        46
# 2    1/3/2016           40        47
# 3    1/4/2016           25        44
# 4    1/5/2016           20        41
# 5    1/6/2016           33        35
# 6    1/7/2016           39        33
# 7    1/8/2016           39        64
# 8    1/9/2016           44        77
# 9   1/10/2016           50        71
# 10  1/11/2016           33        37
# 11  1/12/2016           35        53
# 12  1/13/2016           26        42
# 13  1/14/2016           30        47
# 14  1/15/2016           43        62
# 15  1/16/2016           47        70
# 16  1/17/2016           36        66
# 17  1/18/2016           25        53
# 18  1/19/2016           22        42
# 19  1/20/2016           32        49
# 20  1/21/2016           31        45
# 21  1/22/2016           26        41
# 22  1/23/2016           26        78
# 23  1/24/2016           28        53
# ...

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#using python
# with open("nyc_weather.csv", "r") as file:
#     for line in file:
#         print(line)

# %%
type(df[["Temperature", "EST"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["EST"])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.mean()
# Out:
# Temperature              34.677419
# DewPoint                 17.838710
# Humidity                 51.677419
# Sea Level PressureIn     29.992903
# VisibilityMiles           9.193548
# WindSpeedMPH              6.892857
# CloudCover                3.129032
# WindDirDegrees          247.129032
# dtype: float64

# %%
df["Temperature"].min()
# Out:
# 20

# %%
df["WindSpeedMPH"][df["Temperature"] == df["Temperature"].min()]
# Out:
# 4    5.0
# Name: WindSpeedMPH, dtype: float64

# %%
df["EST"][df["Temperature"] == df["Temperature"].max()]
# Out:
# 9    1/10/2016
# Name: EST, dtype: object

# %%
df["EST"][df["Events"] == "Rain"]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df_copy["WindSpeedMPH"].fillna(9999, inplace = True) #FILL NAN values using zero
df_copy["WindSpeedMPH"].fillna(df["WindSpeedMPH"].mean(), inplace = True) #fill NAN values with mean
df_copy
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
new_col = pd.Series([i for i in range(31)])
df["new_col"] = new_col
df
# df[['Temperature', 'EST']]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %% [markdown]
# ## **CREATING DF BASICS**

# %%
weather_data = {
    'day': ['1/1/2017', '2/1/2017','3/1/2017','4/1/2017','5/1/2017','7/1/2017','8/1/2017'],
    'temperature': [32,28,30,29,20, 21, 24],
    'windspeed': [6,7,10,7,4,6,8],
    'event': ['Rain', 'Snow', 'Snow', 'Hail', 'Rain', 'Hail', 'Rain']
}
weather_data['temperature'][0:2]
# Out:
# [32, 28]

# %%
type(weather_data)
# Out:
# dict

# %%
df2 = pd.DataFrame(weather_data)

# %%
df2
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 1  2/1/2017           28          7  Snow
# 2  3/1/2017           30         10  Snow
# 3  4/1/2017           29          7  Hail
# 4  5/1/2017           20          4  Rain
# 5  7/1/2017           21          6  Hail
# 6  8/1/2017           24          8  Rain

# %%
df2.shape
# Out:
# (7, 4)

# %%
df2.head()
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 1  2/1/2017           28          7  Snow
# 2  3/1/2017           30         10  Snow
# 3  4/1/2017           29          7  Hail
# 4  5/1/2017           20          4  Rain

# %%
df2.tail(3)#last n data points
# Out:
#         day  temperature  windspeed event
# 4  5/1/2017           20          4  Rain
# 5  7/1/2017           21          6  Hail
# 6  8/1/2017           24          8  Rain

# %%
new_df = df2[1:5]

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df.Temperature.max()
# Out:
# 50

# %%
df2[df2['temperature']>29]
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 2  3/1/2017           30         10  Snow

# %%
df[df['Temperature'] == df.Temperature.max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
# df['day'][df['temperature'] == df['temperature'].max()]
seri = pd.Series({'new_guy': [6,7,10,7,4,6,8]})#CREATE A NEW SERIES

# %%
seri
# Out:
# new_guy    [6, 7, 10, 7, 4, 6, 8]
# dtype: object

# %%
df2['new_guy'] = seri
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-15d18dd56e4e> in <module>()
# ----> 1 df2['new_guy'] = seri
#       2 df2
#
# NameError: name 'seri' is not defined

# %%
list(seri)[0]
# Out:
# [6, 7, 10, 7, 4, 6, 8]

# %%
df2['new_guy'] = [6, 7, 10, 7, 4, 6, 8]

# %%
df2
# Out:
#         day  temperature  windspeed event  new_guy
# 0  1/1/2017           32          6  Rain        6
# 1  2/1/2017           28          7  Snow        7
# 2  3/1/2017           30         10  Snow       10
# 3  4/1/2017           29          7  Hail        7
# 4  5/1/2017           20          4  Rain        4
# 5  7/1/2017           21          6  Hail        6
# 6  8/1/2017           24          8  Rain        8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 12 columns):
# EST                     31 non-null object
# Temperature             31 non-null int64
# DewPoint                31 non-null int64
# Humidity                31 non-null int64
# Sea Level PressureIn    31 non-null float64
# VisibilityMiles         31 non-null int64
# WindSpeedMPH            28 non-null float64
# PrecipitationIn         31 non-null object
# CloudCover              31 non-null int64
# Events                  9 non-null object
# WindDirDegrees          31 non-null int64
# new_col                 31 non-null int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 3.0+ KB

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees    new_col
# count        31.000000     28.000000   31.000000       31.000000  31.000000
# mean          9.193548      6.892857    3.129032      247.129032  15.000000
# std           1.939405      2.871821    2.629853       92.308086   9.092121
# min           1.000000      2.000000    0.000000       34.000000   0.000000
# ...

# %%
df.describe(include = "O")
# Out:
#               EST PrecipitationIn Events
# count          31              31      9
# unique         31               7      3
# top     1/16/2016               0   Rain
# freq            1              19      4

# %%
x = df.corr()

# %%
x.columns
# Out:
# Index(['Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'CloudCover', 'WindDirDegrees',
#        'new_col'],
#       dtype='object')
