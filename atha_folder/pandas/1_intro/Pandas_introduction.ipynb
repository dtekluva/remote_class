# %%
import pandas as pd

# %%
new_df = pd.DataFrame(dict(names = ["ade", "jonah", "sule", "monica", "laide"], 
                           ages = [34,45,12,54,13], 
                           hobbies = ["dancing", "dancing", "runing", "singing", "reading"]))

# %%
new_df
# Out:
#     names  ages  hobbies
# 0     ade    34  dancing
# 1   jonah    45  dancing
# 2    sule    12   runing
# 3  monica    54  singing
# 4   laide    13  reading

# %%
type(new_df)
# Out:
# pandas.core.frame.DataFrame

# %%
new_series = pd.Series(["29/11/2013", "10/01/2012", "15/03/2019", "30/12/2017", "19/07/2017" ])

# %%
type(new_series)
# Out:
# pandas.core.series.Series

# %%
new_df["application_date"] = new_series

# %%
new_df
# Out:
#     names  ages  hobbies application_date
# 0     ade    34  dancing       29/11/2013
# 1   jonah    45  dancing       10/01/2012
# 2    sule    12   runing       15/03/2019
# 3  monica    54  singing       30/12/2017
# 4   laide    13  reading       19/07/2017

# %%
new_series2 = pd.Series(["09/11/2013", "10/02/2012", "14/04/2019", "30/01/2019", "19/10/2017" ])

# %%
new_df["approval_date"] = new_series

# %%
new_df
# Out:
#     names  ages  hobbies application_date approval_date
# 0     ade    34  dancing       29/11/2013    29/11/2013
# 1   jonah    45  dancing       10/01/2012    10/01/2012
# 2    sule    12   runing       15/03/2019    15/03/2019
# 3  monica    54  singing       30/12/2017    30/12/2017
# 4   laide    13  reading       19/07/2017    19/07/2017

# %%
new_df.to_csv("applicants.csv")

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
# names               5 non-null object
# ages                5 non-null int64
# hobbies             5 non-null object
# application_date    5 non-null object
# approval_date       5 non-null object
# dtypes: int64(1), object(4)
# memory usage: 280.0+ bytes

# %% [markdown]
# ###### READ CSV WITH PANDAS

# %%
read_df = pd.read_csv("applicants.csv")

# %%
read_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
# Unnamed: 0          5 non-null int64
# names               5 non-null object
# ages                5 non-null int64
# hobbies             5 non-null object
# application_date    5 non-null object
# approval_date       5 non-null object
# dtypes: int64(2), object(4)
# memory usage: 320.0+ bytes

# %%
read_df.describe()
# Out:
#        Unnamed: 0       ages
# count    5.000000   5.000000
# mean     2.000000  45.200000
# std      1.581139  24.752778
# min      0.000000  13.000000
# 25%      1.000000  34.000000
# 50%      2.000000  45.000000
# 75%      3.000000  54.000000
# max      4.000000  80.000000

# %%
#drop column named unknown
read_df = read_df.drop(columns = ["Unnamed: 0"])

# %%
read_df.describe()
# Out:
#             ages
# count   5.000000
# mean   45.200000
# std    24.752778
# min    13.000000
# 25%    34.000000
# 50%    45.000000
# 75%    54.000000
# max    80.000000

# %%
read_df.describe(include = ['O'])
# Out:
#        names  hobbies application_date approval_date
# count      5        5                5             5
# unique     5        4                5             5
# top     sule  dancing       15/03/2019    15/03/2019
# freq       1        2                1             1

# %%
read_df.ages.max()
# Out:
# 80

# %%
read_df.ages.min()
# Out:
# 13

# %%
read_df.ages==13
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: ages, dtype: bool

# %%
read_df[read_df.ages==13]
# Out:
#    names  ages  hobbies application_date approval_date
# 4  laide    13  reading       19/07/2017    19/07/2017

# %%
read_df[read_df.ages==54]
# Out:
#     names  ages  hobbies application_date approval_date
# 3  monica    54  singing       30/12/2017    30/12/2017

# %%
max_age = read_df.ages.max()
read_df[read_df.ages==max_age]
# Out:
#   names  ages hobbies application_date approval_date
# 2  sule    80  runing       15/03/2019    15/03/2019

# %%
read_df.plot("names", "ages", kind = "barh", color = ["red", "blue", "green", "yellow", "orange"])

# %%
sales_data = pd.read_csv("sales.csv")

# %%
sales_data.head()
# Out:
#    index  monday  tuesday  wednesday  thursday  friday  saturday  sunday
# 0      0     923      631        935       371     756      3166     114
# 1      1     918      626        930       366     751      3161     109
# 2      2     497      305        403       239     434       824      67
# 3      3     499      307        405       241     436       826      69
# 4      4     501      309        407       243     438       828      71

# %%
sales_data.tail()
# Out:
#      index  monday  tuesday  wednesday  thursday  friday  saturday  sunday
# 100    100     855      428        630       254     511      2318     203
# 101    101    1283      641        945       381     766      3476     304
# 102    102    1183      641        945       381     766      3426     274
# 103    103    1133      641        945       381     766      3376     244
# 104    104    1133      641        945       381     766      3376     244

# %%
sales_data = sales_data.drop(columns = ["index", "friday"])

# %%
sales_data.describe()
# Out:
#             monday     tuesday   wednesday    thursday     saturday  \
# count   105.000000  105.000000  105.000000  105.000000   105.000000
# mean    597.866667  365.400000  512.400000  251.276190  1435.504762
# std     214.858275  126.716112  212.547081   70.409174   816.576756
# min     380.000000  190.000000  280.000000  113.000000   824.000000
# 25%     500.000000  305.000000  403.000000  200.000000   852.000000
# 50%     521.000000  329.000000  425.000000  253.000000  1130.000000
# 75%     570.000000  360.000000  450.000000  283.000000  1200.000000
# max    1283.000000  641.000000  945.000000  381.000000  3476.000000
#
#            sunday
# count  105.000000
# mean    96.276190
# std     58.349329
# min     30.000000
# 25%     73.000000
# 50%     90.000000
# 75%     90.000000
# max    304.000000

# %%
import pandas as pd
data = pd.read_csv('nyc_weather.csv')

# %%
max_temp = data.Temperature.max()

# %%
data[data.Temperature == max_temp]
df = data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
# EST                     31 non-null object
# Temperature             31 non-null int64
# DewPoint                31 non-null int64
# Humidity                31 non-null int64
# Sea Level PressureIn    31 non-null float64
# VisibilityMiles         31 non-null int64
# WindSpeedMPH            28 non-null float64
# PrecipitationIn         31 non-null object
# CloudCover              31 non-null int64
# Events                  9 non-null object
# WindDirDegrees          31 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.7+ KB

# %%
data
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                10           8.0               0           5       NaN
# 1                10           7.0               0           3       NaN
# 2                10           8.0               0           1       NaN
# 3                10           9.0               0           3       NaN
# 4                10           5.0               0           0       NaN
# 5                10           4.0               0           0       NaN
# 6                10           2.0               0           3       NaN
# 7                10           4.0               0           8       NaN
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 10               10           NaN               0           1       NaN
# 11               10           6.0               T           4       NaN
# 12               10          10.0               0           0       NaN
# 13               10           5.0               T           7       NaN
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1       NaN
# 19               10           6.0               0           2       NaN
# 20               10           6.0               0           1       NaN
# 21                9           NaN            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2       NaN
# 25               10           7.0               0           2       NaN
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1       NaN
# 28               10           8.0               0           4       NaN
# 29               10           7.0               0           0       NaN
# 30               10           5.0               0           0       NaN
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
data.describe(include = "O")
# Out:
#               EST PrecipitationIn Events
# count          31              31      9
# unique         31               7      3
# top     1/24/2016               0   Rain
# freq            1              19      4

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df.Events.fillna(0, inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                10           8.0               0           5         0
# 1                10           7.0               0           3         0
# 2                10           8.0               0           1         0
# 3                10           9.0               0           3         0
# 4                10           5.0               0           0         0
# 5                10           4.0               0           0         0
# 6                10           2.0               0           3         0
# 7                10           4.0               0           8         0
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 10               10           NaN               0           1         0
# 11               10           6.0               T           4         0
# 12               10          10.0               0           0         0
# 13               10           5.0               T           7         0
# 14                9           5.0               T           2         0
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1         0
# 19               10           6.0               0           2         0
# 20               10           6.0               0           1         0
# 21                9           NaN            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2         0
# 25               10           7.0               0           2         0
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1         0
# 28               10           8.0               0           4         0
# 29               10           7.0               0           0         0
# 30               10           5.0               0           0         0
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
my_data = [{"name":"Attah","age":20}, {"name":"Bolu","age":30}]

# %%
pd.DataFrame(my_data)
# Out:
#    age   name
# 0   20  Attah
# 1   30   Bolu

# %%
df.iloc[10]
# Out:
# EST                     1/11/2016
# Temperature                    33
# DewPoint                        8
# Humidity                       37
# Sea Level PressureIn        29.92
# VisibilityMiles                10
# WindSpeedMPH                  NaN
# PrecipitationIn                 0
# CloudCover                      1
# Events                          0
# WindDirDegrees                289
# Name: 10, dtype: object
